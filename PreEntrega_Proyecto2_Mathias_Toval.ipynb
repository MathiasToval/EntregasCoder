# %% [markdown]
# ---

# %% [markdown]
# #***ABSTRACT***
# **DATASET SPOTIFY TOP HITS 2000-2019**

# %% [markdown]
# En la industria musical actual, gran parte del éxito de un artista se mide y tiene una estrecha correlación con la cantidad de reproducciones e interacciones positivas que tengan sus canciones en las plataformas de streaming. Un ejemplo de estas es Spotify. En la actualidad, tener un éxito viral dentro de la plataforma de streaming con mayor cantidad de usuarios a nivel mundial puede cambiar la carrera de un artista de la noche a la mañana.
#
# Spotify cuenta con una inmensa cantidad de datos sobre los gustos de sus usuarios y las características musicales/sonoras de las canciones que escuchan. Por lo tanto, ¿qué pasaría si pudiéramos aprovechar toda esta información para predecir cuál será la próxima canción que se convertirá en un éxito global?
#
# Ese es justamente el objetivo del proyecto. Se utilizará un conjunto de datos de Spotify que incluye las características de las canciones más destacadas en la plataforma, entre 2000 y 2019.

# %% [markdown]
# El dataset elegido fue "TOP HITS SPOTIFY 2000-2019". Dicho dataset provee información sobre las distintas características tanto acústicas como musicales de las canciones más exitosas dentro de una de las plataformas de streaming más utilizadas en las últimas décadas.
#
# En cuanto a un análisis de los datos, es posible observar la forma en la que fue desarrollándose la industria musical global en los últimos años. Desde la manera en la que fueron evolucionando las características tonales y emocionales de las canciones, hasta las características de intensidad y nivel de sonoridad que se fueron desarrollando en los últimos tiempos.
#
# Esta información permitiría descifrar si existe alguna correlación entre la composición y masterización de los temas con su popularidad. Y a la vez, determinar cómo se fueron desarrollando las diferentes tendencias musicales, que muchas veces representan el pensamiento o estado emocional general de la sociedad.
#
# Algunos ejemplos más específicos de análisis son:
#
# 1. Relación entre sonoridad y popularidad de un HIT en las últimas dos décadas. Pudiendo así determinar si dichos éxitos se deben en parte al gusto general por niveles de presión sonora más altos o son consecuencia del avance tecnológico en los distintos equipos de audio.
# 2. El análisis de la duración de los éxitos y su correlación con su popularidad y género musical. Ahondando así en qué estándares fija la sociedad/industria musical y cómo se relaciona esto con el tiempo de concentración y atención a nivel cognitivo del humano o la relación de la duración con la cultura de la inmediatez.
# 3. La existencia de alguna correspondencia entre las características musicales de las canciones, como el tono, tempo, modo (si es una tonalidad menor o mayor), "energía" o ritmo con el éxito comercial de la canción.
#
#
# A partir de dichos análisis se pretende poder determinar con qué nivel de exactitud se puede predecir las características musicales y acústicas de los próximos éxitos musicales, generando una herramienta útil para la toma de decisiones de distintas productoras o sellos discográficos sobre qué camino tomar a la hora de invertir recursos en determinados artistas.

# %% [markdown]
# #Enumeración de fases importantes para la resolución del caso
#
# En base al análisis realizado, se estableceran las siguientes secciones

# %% [markdown]
# # 1. **DEFINICIÓN DE OBJETIVO:**
#
# Nuestro objetivo es dilucidar si existe alguna forma de poder predecir cuáles serían las características musicales y acústicas de una canción que puedan originar un éxito comercial.

# %% [markdown]
# # 2. **CONTEXTO COMERCIAL:**
# Con el auge de las distintas plataformas de streaming en las últimas décadas, el modelo de negocio en la industria musical dejó de basarse únicamente en una relación de dependencia entre el artista y un sello musical o productora para poder masificar el alcance de determinado álbum o sencillo. Ahora, los artistas independientes tienen la oportunidad de llegar a cientos de personas sin tener que depender únicamente de alguna entidad comercial para obtener una conexión con su público.
#
# Aun así, la brecha entre la capacidad de alcance y recursos entre un artista independiente y otro con acceso a una productora sigue siendo significativa. Por eso, a través de este trabajo, se busca identificar patrones dentro de las canciones de éxito de las últimas dos décadas para poder encontrar las características necesarias o definitorias que puedan ayudar a los artistas independientes en la elección de las distintas componentes de su música o mezcla. De esta forma, se pretende, en cierta medida, acortar la brecha.
#
# Otro punto importante a recalcar frente al contexto comercial es la forma en la que se define el éxito comercial de una canción:
#
# Un éxito comercial se puede definir como la capacidad de un producto, en este caso una canción u obra musical, para generar ganancias significativas y sostenidas en el mercado. Esto implica alcanzar y superar los objetivos de ventas, obtener beneficios económicos y lograr un reconocimiento positivo en el ámbito empresarial.
#
# Por lo tanto, la popularidad en Spotify puede influir en el éxito comercial de un artista o canción al proporcionar una amplia exposición a una audiencia global y generar ingresos a través de las reproducciones y suscripciones. Sin embargo, es importante tener en cuenta que la popularidad en Spotify no es el único factor determinante del éxito comercial, ya que existen otros aspectos como la calidad de la música, la promoción adecuada y la gestión efectiva de la carrera artística.

# %% [markdown]
# # 3. **PROBLEMA COMERCIAL:**
# En base a los datos obtenidos, nuestra misión será manipularlos para obtener visualizaciones que respondan a diferentes preguntas y determinen cuál es la correlación entre las características tonales y acústicas de una canción con su éxito comercial.
#
# * ¿Existe relación entre la sonoridad y popularidad de un HIT en las últimas dos décadas?
# * ¿Cuál es la duración estándar de un éxito comercial?
# * ¿Qué género musical tiene más probabilidades de ser exitoso?
# * ¿El nivel energético de una canción determina su popularidad?
# * ¿Qué tonos musicales son los más usados por los artistas top de Spotify?
# * ¿Qué relación hay entre el modo de una canción y su popularidad?
#
# A través del análisis de estos aspectos, podremos obtener una mejor comprensión de cómo las características musicales influyen en el éxito comercial de una canción.

# %% [markdown]
# # 4. **CONTEXTO ANALITICO:**
# El Dataset a utilizar será ["TOP HITS SPOTIFY 2000-2019"](https://www.kaggle.com/datasets/paradisejoy/top-hits-spotify-from-20002019). Dicho dataset provee información sobre las distintas características tanto acústicas como musicales de las canciones más exitosas dentro de una de las plataformas de streaming más utilizadas en las últimas décadas.
#
# A continuación, se especifican las características de cada campo del dataset:
#
# 1. **artist**: Nombre del artista.
#
# 2. **song**: Nombre de la pista.
#
# 3. **duration_ms**: duración de la pista en milisegundos.
#
# 4. **explicit**: La letra o el contenido de una canción o un video musical contienen uno o más de los criterios que podrían considerarse ofensivos o inadecuados para los niños.
#
# 5. **age**: Año de lanzamiento de la pista.
#
# 6. **popularity**: cuanto mayor sea el valor, más popular es la canción.
#
# 7. **danceability**: DanceAbility describe cuán adecuada es una pista para bailar basada en una combinación de elementos musicales que incluyen tempo, estabilidad de ritmo, fuerza de ritmo y regularidad general. Un valor de 0.0 es menos bailable y 1.0 es más bailable.
#
# 8. **energy**: la energía es una medida de 0.0 a 1.0 y representa una medida perceptiva de intensidad y actividad.
#
# 9. **key**: la clave en la que se encuentra la pista. Utilizando notación de tipo de tono estándar. P.ej. 0 = C, 1 = C♯/D ♭, 2 = D, y así sucesivamente. Si no se detectó ninguna clave, el valor es -1.
#
# 10. **loudness**: representa el volumen general de una pista en Decibeles (DB). Los valores de volumen se promedian en toda la pista y son útiles para comparar el volumen relativo de las pistas.
#
# 11. **mode**: el modo indica la modalidad (mayor o menor) de una pista, el tipo de escala a partir de la cual se deriva su contenido melódico. Mayor está representado por 1 y menor es 0.
#
# 12. **speechiness**: detecta la presencia de palabras habladas en una pista. Cuanto más hablada sea la grabación (por ejemplo, programa de entrevistas, audiolibro, poesía), más cerca de 1.0 el valor del atributo. Los valores superiores a 0.66 describen pistas que probablemente se hagan completamente de palabras habladas. Los valores entre 0.33 y 0.66 describen pistas que pueden contener música y discurso, ya sea en secciones o en capas, incluidos casos como la música rap. Los valores por debajo de 0.33 probablemente representan música y otras pistas sin voz.
#
# 13. **acousticness**: una medida de confianza de 0.0 a 1.0 de si la pista es acústica. 1.0 representa una alta confianza, la pista es acústica.
#
# 14. **instrumentalness**: predice si una pista no contiene voces. Los sonidos "OOH" y "AAH" se tratan como instrumentales en este contexto. Las pistas de rap o palabras habladas son claramente "vocales". Cuanto más cerca sea el valor de instrumentalidad a 1.0, mayor es la probabilidad de que la pista no contenga contenido vocal. Los valores superiores a 0.5 están destinados a representar pistas instrumentales, pero la confianza es mayor a medida que el valor se acerca a 1.0.
#
# 15. **liveness**: detecta la presencia de una audiencia en la grabación. Los valores de vida más altos representan una mayor probabilidad de que la pista se haya realizado en vivo. Un valor superior a 0.8 proporciona una fuerte probabilidad de que la pista esté en vivo.
#
# 16. **valence**: una medida de 0.0 a 1.0 que describe la positividad musical transmitida por una pista. Las pistas con alta valencia suenan más positivas (por ejemplo, felices, alegres, eufóricas), mientras que las pistas con baja valencia suenan más negativas (por ejemplo, triste, deprimida, enojada).
#
# 17. **tempo**: el tempo estimado general de una pista en ritmos por minuto (BPM). En la terminología musical, el tempo es la velocidad o el ritmo de una pieza dada y deriva directamente de la duración promedio del latido.
#
#
# 18. **genre**: Género de la pista.

# %% [markdown]
# #DATA UNDERSTADING

# %% [markdown]
# Planteo librerias potenciales a utilizar

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import missingno as msno 
import sklearn

url = "https://raw.githubusercontent.com/MathiasToval/coder1/main/songs_normalize.csv"
df_v1 = pd.read_csv(url)
df_v1.head()
# Out:
#            artist                    song  duration_ms  explicit  year  \
# 0  Britney Spears  Oops!...I Did It Again       211160     False  2000
# 1       blink-182    All The Small Things       167066     False  1999
# 2      Faith Hill                 Breathe       250546     False  1999
# 3        Bon Jovi            It's My Life       224493     False  2000
# 4          *NSYNC             Bye Bye Bye       200560     False  2000
#
#    popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0          77         0.751   0.834    1    -5.444     0       0.0437
# 1          79         0.434   0.897    0    -4.918     1       0.0488
# 2          66         0.529   0.496    7    -9.007     1       0.0290
# 3          78         0.551   0.913    0    -4.063     0       0.0466
# 4          65         0.614   0.928    8    -4.806     0       0.0516
#
#    acousticness  instrumentalness  liveness  valence    tempo         genre
# 0        0.3000          0.000018    0.3550    0.894   95.053           pop
# 1        0.0103          0.000000    0.6120    0.684  148.726     rock, pop
# 2        0.1730          0.000000    0.2510    0.278  136.859  pop, country
# 3        0.0263          0.000013    0.3470    0.544  119.992   rock, metal
# 4        0.0408          0.001040    0.0845    0.879  172.656           pop

# %% [markdown]
# # 5. **EXPLORATORY DATA ANALYSIS:**

# %% [markdown]
# # DATA WRANGLING

# %% [markdown]
# * Para poder utilizar el campo de géneros en ciertas instancias durante el proyecto, se crea un diccionario vacío y luego se recorre la columna para asignar un ID a cada valor único.
#
#
# * Se crea una columna llamada numero_genero para posteriores análisis
#
#
# * Tambien se pasa la duración en milisegundos de los temas a segundos.

# %%
# Se obtiene una lista de los valores únicos en la columna 'genero'
generos_unicos = df_v1['genre'].unique()

# Se crea un diccionario que asigna un número a cada valor único en la lista 'generos_unicos'
generos_dict = {genero: i for i, genero in enumerate(generos_unicos)}

# Se reemplaza los valores en la columna 'genero' con los números asignados en el diccionario
df_v1['numero_genero'] = df_v1['genre'].replace(generos_dict)

# Paso duracion de milisegundos a segundos, para una mejor visualización
df_v1 = df_v1.rename(columns={'duration_ms': 'duration_s'})
df_v1["duration_s"] = df_v1["duration_s"] / 1000

# %% [markdown]
# * Como nuestro analisis se basará en la popularidad de los distintos HITS de SPOTIFY. Procedemos a filtrar aquellos temas que planteen una popularidad nula.

# %%
#Filtramos las filas con popularidad igual a 0
filtro = df_v1['popularity'] > 0
df_v1 = df_v1[filtro]

# %% [markdown]
# * Teniendo en cuenta que buscamos predecir si una canción será o no un HIT con una popularidad considerable. Para esto creamos una nueva columna en la que se determine si un tema es un HIT o no. Estableciendo como medida necesaria, que la popularidad de este sea mayor de 50 para ser considerado HIT

# %%
df_v1['hit'] = df_v1['popularity'].apply(lambda x: 1 if x > 50 else 0)

# %% [markdown]
# Por lo tanto, en una primera instancia, este seria la configuración del dataset original.

# %%
df_v1.head()
# Out:
#            artist                    song  duration_s  explicit  year  \
# 0  Britney Spears  Oops!...I Did It Again     211.160     False  2000
# 1       blink-182    All The Small Things     167.066     False  1999
# 2      Faith Hill                 Breathe     250.546     False  1999
# 3        Bon Jovi            It's My Life     224.493     False  2000
# 4          *NSYNC             Bye Bye Bye     200.560     False  2000
#
#    popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0          77         0.751   0.834    1    -5.444     0       0.0437
# 1          79         0.434   0.897    0    -4.918     1       0.0488
# 2          66         0.529   0.496    7    -9.007     1       0.0290
# 3          78         0.551   0.913    0    -4.063     0       0.0466
# 4          65         0.614   0.928    8    -4.806     0       0.0516
#
#    acousticness  instrumentalness  liveness  valence    tempo         genre  \
# 0        0.3000          0.000018    0.3550    0.894   95.053           pop
# 1        0.0103          0.000000    0.6120    0.684  148.726     rock, pop
# 2        0.1730          0.000000    0.2510    0.278  136.859  pop, country
# 3        0.0263          0.000013    0.3470    0.544  119.992   rock, metal
# 4        0.0408          0.001040    0.0845    0.879  172.656           pop
#
#    numero_genero  hit
# 0              0    1
# 1              1    1
# 2              2    1
# 3              3    1
# 4              0    1

# %% [markdown]
# * A continuación, crearemos un nuevo Dataframe, sumando nuevos datos al dataframe original. Para esto se utilizará la API de Spotify.

# %% [markdown]
# # API SPOTIFY

# %% [markdown]
# Por medio de "Spotify for Developers" obtenemos las claves de *Client ID* y *Client Secret*. Tambien procedemos a instalar el paquete "spotipy".

# %% [markdown]
# ![WhatsApp Image 2023-03-26 at 20.11.11.jpeg](data:image/jpeg;base64,...)

# %%
pip install spotipy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spotipy in /usr/local/lib/python3.10/dist-packages (2.23.0)
# Requirement already satisfied: redis>=3.5.3 in /usr/local/lib/python3.10/dist-packages (from spotipy) (4.5.5)
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (1.26.15)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (2.27.1)
# Requirement already satisfied: async-timeout>=4.0.2 in /usr/local/lib/python3.10/dist-packages (from redis>=3.5.3->spotipy) (4.0.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (2022.12.7)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

client_id = "d7389afe90bf4ad1b043461a01439f72"

client_secret = "ce287311b62346ba9052e971edbb6df3"

#Inicio sesión en cuenta de Spotify desde código de Python

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# Crearemos un dataframe con los datos que nos provea la API. Para esto tomamos todos aquellos datos que se encuentren entre el 2000 y 2019, tal como el dataset original.

# %%
# Defino el período de tiempo que se va a buscar
start_year = 2000
end_year = 2019

# Buscar las pistas más populares de ese período de tiempo
tracks = []
for year in range(start_year, end_year+1):
    result = sp.search(q='year:'+str(year), type='track', limit=50)
    tracks += result['tracks']['items']

# %%
# Obtengo las características de audio de cada pista y se guardan en una lista
features = []
for track in tracks:
    audio_features = sp.audio_features(track['uri'])[0]
    audio_features['song'] = track['name']
    audio_features['artist'] = track['artists'][0]['name']
    audio_features['explicit'] = track['explicit']
    audio_features['popularity']=track['popularity']
    audio_features['duration_ms']=track['duration_ms']
    audio_features['year'] = track['album']['release_date'][:4]

    artist_id = track['artists'][0]['id']
    artist_info = sp.artist(artist_id)
    genre = artist_info['genres']
    
    audio_features['genre'] = genre
    
    features.append(audio_features)
  
df_api = pd.DataFrame(features)

# %%
#Imprimo Dataset de API
df_api.tail()
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 995         0.635   0.537    7    -7.895     0       0.0832        0.1720
# 996         0.704   0.225    6   -14.454     0       0.0994        0.9020
# 997         0.745   0.642    7    -6.257     0       0.2870        0.0204
# 998         0.459   0.575    3    -4.858     1       0.0573        0.6040
# 999         0.421   0.539   11    -5.456     0       0.2740        0.7790
#
#      instrumentalness  liveness  valence  ...  \
# 995             0.000    0.4180    0.383  ...
# 996             0.657    0.1060    0.243  ...
# 997             0.000    0.0658    0.226  ...
# 998             0.000    0.0885    0.183  ...
# 999             0.000    0.1110    0.523  ...
#
#                                             track_href  \
# 995  https://api.spotify.com/v1/tracks/3wwo0bJvDSor...
# 996  https://api.spotify.com/v1/tracks/3ZCTVFBt2Brf...
# 997  https://api.spotify.com/v1/tracks/1lOe9qE0vR9z...
# 998  https://api.spotify.com/v1/tracks/2gMXnyrvIjhV...
# 999  https://api.spotify.com/v1/tracks/4Wjhj0WjkyEC...
#
#                                           analysis_url duration_ms  \
# 995  https://api.spotify.com/v1/audio-analysis/3wwo...      215380
# 996  https://api.spotify.com/v1/audio-analysis/3ZCT...      245425
# 997  https://api.spotify.com/v1/audio-analysis/1lOe...      131240
# 998  https://api.spotify.com/v1/audio-analysis/2gMX...      215106
# 999  https://api.spotify.com/v1/audio-analysis/4Wjh...      281518
#
#     time_signature                                  song         artist  \
# 995              4  Let Me Know (I Wonder Why Freestyle)     Juice WRLD
# 996              4                   everything i wanted  Billie Eilish
# 997              4                                Ransom      Lil Tecca
# 998              4                         Before You Go  Lewis Capaldi
# 999              3                          Trust Issues          Drake
#
#      explicit  popularity  year  \
# 995      True          79  2019
# 996     False          85  2019
# 997      True          82  2019
# 998     False          86  2019
# 999      True          81  2019
#
#                                                  genre
# 995                    [chicago rap, melodic rap, rap]
# 996                         [art pop, electropop, pop]
# 997                        [melodic rap, pluggnb, rap]
# 998                                      [pop, uk pop]
# 999  [canadian hip hop, canadian pop, hip hop, rap,...
#
# [5 rows x 24 columns]

# %%
#Eliminamos las columnas que no coincidan con el dataframe original
df_api = df_api.drop(columns=['uri', 'track_href','analysis_url','time_signature','type','id'])

# %%
#Se aplica el mismo formato a la columna generos, para eso se quitan corchetes y comillas

df_api['genre'] = df_api['genre'].apply(lambda x: ', '.join([s.replace("'", "") if isinstance(s, str) else s for s in x]))

def quitar_corchetes(lista):
    cadena = str(lista)
    cadena = cadena.replace("[", "").replace("]", "")
    return cadena

# aplica la función a la columna 'generos' del dataframe
df_api['genre'] = df_api['genre'].apply(quitar_corchetes)
df_api['genre'] = df_api['genre'].str.replace("'", "")

# Se obtiene una lista de los valores únicos en la columna 'genero'
generos_unicos = df_api['genre'].unique()

# Se crea un diccionario que asigna un número a cada valor único en la lista 'generos_unicos'
generos_dict = {genero: i for i, genero in enumerate(generos_unicos)}

# Se reemplaza los valores en la columna 'genero' con los números asignados en el diccionario
df_api['numero_genero'] = df_api['genre'].replace(generos_dict)

# Paso duracion de milisegundos a segundos, para una mejor visualización
df_api = df_api.rename(columns={'duration_ms': 'duration_s'})
df_api["duration_s"] = df_api["duration_s"] / 1000

#se crea la columna hit en el nuevo data frame
df_api['hit'] = df_api['popularity'].apply(lambda x: 1 if x > 50 else 0)

df_api
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.371   0.268    1   -10.506     1       0.0281       0.74800
# 1           0.949   0.661    5    -4.244     0       0.0572       0.03020
# 2           0.429   0.661   11    -7.227     1       0.0281       0.00239
# 3           0.843   0.806    4    -5.946     0       0.2690       0.14300
# 4           0.545   0.865   11    -5.708     0       0.0286       0.00664
# ..            ...     ...  ...       ...   ...          ...           ...
# 995         0.635   0.537    7    -7.895     0       0.0832       0.17200
# 996         0.704   0.225    6   -14.454     0       0.0994       0.90200
# 997         0.745   0.642    7    -6.257     0       0.2870       0.02040
# 998         0.459   0.575    3    -4.858     1       0.0573       0.60400
# 999         0.421   0.539   11    -5.456     0       0.2740       0.77900
#
#      instrumentalness  liveness  valence    tempo  duration_s  \
# 0            0.051700    0.1040    0.165  102.617     227.093
# 1            0.000000    0.0454    0.760  104.504     284.200
# 2            0.000121    0.2340    0.285  173.372     266.773
# 3            0.000000    0.0771    0.613   94.948     270.506
# 4            0.000011    0.1680    0.543   99.009     233.933
# ..                ...       ...      ...      ...         ...
# 995          0.000000    0.4180    0.383  125.028     215.380
# 996          0.657000    0.1060    0.243  120.006     245.425
# 997          0.000000    0.0658    0.226  179.974     131.240
# 998          0.000000    0.0885    0.183  111.881     215.106
# 999          0.000000    0.1110    0.523   89.177     281.518
#
#                                      song         artist  explicit  \
# 0                                  Sparks       Coldplay     False
# 1                     The Real Slim Shady         Eminem      True
# 2                                  Yellow       Coldplay     False
# 3                             Ms. Jackson        Outkast      True
# 4                              Kryptonite   3 Doors Down     False
# ..                                    ...            ...       ...
# 995  Let Me Know (I Wonder Why Freestyle)     Juice WRLD      True
# 996                   everything i wanted  Billie Eilish     False
# 997                                Ransom      Lil Tecca      True
# 998                         Before You Go  Lewis Capaldi     False
# 999                          Trust Issues          Drake      True
#
#      popularity  year                                              genre  \
# 0            86  2000                                permanent wave, pop
# 1            88  2000                      detroit hip hop, hip hop, rap
# 2            90  2000                                permanent wave, pop
# 3            83  2000  atl hip hop, dirty south rap, hip hop, old sch...
# 4            81  2000     alternative metal, nu metal, post-grunge, rock
# ..          ...   ...                                                ...
# 995          79  2019                      chicago rap, melodic rap, rap
# 996          85  2019                           art pop, electropop, pop
# 997          82  2019                          melodic rap, pluggnb, rap
# 998          86  2019                                        pop, uk pop
# 999          81  2019  canadian hip hop, canadian pop, hip hop, rap, ...
#
#      numero_genero  hit
# 0                0    1
# 1                1    1
# 2                0    1
# 3                2    1
# 4                3    1
# ..             ...  ...
# 995            355    1
# 996            357    1
# 997            377    1
# 998            297    1
# 999            209    1
#
# [1000 rows x 20 columns]

# %% [markdown]
# Con el nuevo dataframe obtenido, puedo ampliar la cantidad de datos que tenia el dataframe anterior. Ademas, antes de unir ambos dataframe, procedemos a reordenar las columndas de DF_API y corroborar que ambos tengan los mismos tipos de valores.

# %%
#reordeno columnas del nuevo data frame de la misma forma que el original
df_api = df_api.reindex(columns=df_v1.columns)

#igualo formatos del dataframe original
df_api['hit'].fillna(0, inplace=True)
df_api['hit'] = df_api['hit'].astype(int)
df_api['year'] = df_api['year'].astype(int)
df_api['numero_genero'] = df_api['numero_genero'].astype(int)

#CORROBORO QUE LOS FORMATOS EN TODAS LAS COLUMNAS SEAN LOS MISMOS

# Obtener los tipos de datos del primer dataframe
dtypes1 = df_v1.dtypes
# Obtener los tipos de datos del segundo dataframe
dtypes2 = df_api.dtypes

# Obtener las columnas que tienen distintos tipos de datos
diff_cols = set(dtypes1.index) ^ set(dtypes2.index) or \
            set(dtypes1[dtypes1 != dtypes2].index)

# Imprimir las columnas con diferentes tipos de datos
print("Columnas con diferentes tipos de datos:")
print(diff_cols)
# Out:
# Columnas con diferentes tipos de datos:
# set()

# %% [markdown]
# Una vez que las columnas tengan los mismos tipos de datos, concatenamos ambos Dataframes, el original y el que posee los datos provistos por la API. Para generar una nueva version del dataframe con mas datos.

# %%
# CONCATENO AMBOS DATA FRAMES
df = pd.concat([df_v1, df_api], ignore_index=True)

# %% [markdown]
# *   Corroboramos si el dataset no tiene valores faltantes

# %%
msno.matrix(df)
plt.title('Valores Faltantes')
# Out:
# Text(0.5, 1.0, 'Valores Faltantes')

# %% [markdown]
# * Buscamos y borramos valores duplicados

# %%
print('Medidas originales:',df.shape)
df = df.drop_duplicates()
print('Luego de borrar duplicados:',df.shape)
# Out:
# Medidas originales: (2874, 20)
# Luego de borrar duplicados: (2815, 20)

# %% [markdown]
# Con ambos Datasets ya concatenados, podemos proceder a realizar un analisis grafico de dichos datos.

# %% [markdown]
# # **ANÁLISIS GRAFICO**

# %% [markdown]
# # Relación entre sonoridad y popularidad de un HIT en las ultimas dos decadas
# Cuando hablamos de Sonoridad nos referimos alatributo que nos permite ordenar sonidos en una escala del de mayor intensidad al de menor intensidad. Por lo tanto, resulta interesante determinar si existe o no, una relación entre la intensidad general de una canción ("Loudness") y su popularidad ("Popularity")

# %%
popularidad = df["popularity"];
popularidad = popularidad.tolist();
sonoridad = df["loudness"];
sonoridad = sonoridad.tolist();

fig, ax = plt.subplots();
mapeo_colores = ax.scatter(popularidad,sonoridad, c=df["year"]);
fig.colorbar(mapeo_colores)
ax.set_title('Relación entre la sonoridad de una canción y su popularidad');
ax.set_xlabel('Popularidad');
ax.set_ylabel('Sonoridad (dB)');

# %% [markdown]
# Como se puede observar, podemos encontrar cierta cantidad de puntos con popularidad realmente baja. Esto podria ser consecuencia de dos factores claves. El hecho de que el modelo que se haya utilizado para medir la popularidad de las canciones tenga ciertos errores. O, suponiendo que la popularidad del tema se mide en base a la cantidad de reproducciones, se plantea el hecho de que la cantidad de gente que haya escuchado musica en spotify durante los primeros años de medición sea mucho menor que en los ultimos años. Lo cual podria alterar las mediciones.
#
# Aunque esa ultima hipotesis resultaria no ser cierta, debido a que, como se ve en el grafico, la mayoria de los puntos con popularidad muy baja tienen tonalidades mayores a las que corresponden al año 2015. Esto explicaria el hecho de que la cantidad de usuarios durante los años, no sean un factor determinante a la hora de calcular la popularidad de los HITS.
#
# Por estas razones, en ciertos graficos posteriores, se tomó la decisión de darle importancia, principalmente a los valores cuya popularidad se encuentre por encima de 20.

# %% [markdown]
# En cuanto al análisis del grafico en si. La escala que se presenta en el eje Y refiere a "dBFS". La cantidad de decibeles de distancia se encuentra la canción del maximo nivel disponible digitalmente en un sistema especifico. Posterior a los 0dBFS se encontraria la saturación del audio.
#
#  Por lo tanto, se puede observar como en los ultimos años, mas allá de la popularidad del tema, se estuvo tomando como convención el rango de entre los -10 a los -3 dB. Esto puede deberse principalmente a la preferencia de nivel del publico y ademas a las capacidades de los equipos de audio convencionales a traves de la ultima decada.
#
#   En cuanto a la popularidad, se puede ver como la relación es practicamente horizontal, los temas mas populares siempre mantendran el rango dinamico planteado anteriormente.

# %% [markdown]
# # Análisis de la duración de los HITS de las ultimas dos decadas
#
# Otra cuestión importante a señalar, es la duración estandar de las canciones mas relevantes de las ultimas decadas.

# %%
duracion = df["duration_s"]
duracion = duracion.tolist()

fig, ax = plt.subplots(figsize=(8, 4))
ax.hist(duracion, bins=30, color='green') 
ax.set_xlim(left=100, right=370)
ax.set_xscale('linear')
ax.set_xticks([204, 220])
ax.set_xticklabels(['204', '220'])
ax.axvline(x=220.5, color='red')
ax.axvline(x=204, color='red')
ax.set_title('Histograma de Duración de Canciones')
ax.set_xlabel('Segundos (s)');
ax.set_ylabel('Frecuencia absoluta');

# %% [markdown]
# Como suele ser costumbre, desde decadas anteriores. La duración de los temas suele plantearse, mayoritariamente, entre los 3 y 4 minutos. Mas especificamente, entre los 204 y 220 segundos. Esto puede ser consecuencia de dos factores relevantes.
#
# 1. El tiempo de concentración y atención a nivel cognitivo del humano
# 2. La musica como negocio, la industria, y la necesidad de generar una satisfacción inmediata en el oyente

# %%
grouped_df = df.groupby("year")["duration_s"].mean()

sns.set_style("darkgrid")
plt.figure(figsize=(10, 6))
sns.lineplot(x=grouped_df.index, y=grouped_df.values, color="#1DB954", linewidth=2.5)

plt.xlabel("Año", fontsize=12)
plt.ylabel("Duración promedio (segundos)", fontsize=12)
plt.title("Duración de los hits durante los años", fontsize=14)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

plt.show()

# %% [markdown]
# Como se puede ver en el grafico, a traves de los años la duración media de las canciones mas exitosas fue disminuyendo. Esto puede deberse a los cambios en la industria musica. Ya que la industria musical ha experimentado una serie de cambios significativos en las últimas décadas, como la introducción de descargas digitales y servicios de streaming, lo que ha llevado a una mayor competencia y una mayor presión para crear música más accesible y fácil de consumir.

# %% [markdown]
# # Generos musicales mas populares

# %%
import matplotlib.colors as mcolors

fig, ax = plt.subplots(figsize=(12,4))

generos_counts = df["genre"].value_counts()
generos_top_5 = generos_counts.head(5)

colors = ["#1DB954", "#1ED760", "#24A148", "#2EB872", "#32A45F", "#35AB5C", "#39AD51", "#3CB878"]

spotify_colors = mcolors.LinearSegmentedColormap.from_list("spotify_colors", colors)

colormap = spotify_colors
norm = plt.Normalize(vmin=min(generos_top_5.values), vmax=max(generos_top_5.values))

ax.bar(generos_top_5.index, generos_top_5.values,color=colormap(norm(generos_top_5.values)))

ax.set_title("Géneros de canciones más populares")
ax.set_xlabel("Género");
ax.set_ylabel("Frecuencia absoluta");

# %% [markdown]
# Los generos mas escuchados representan la actitud y forma de ser de una generación. Como es común, la musica popular es sino, uno  de los puntos de partida mas relevantes a la hora de hacer un HIT. Aun asi, en las ultimas decadas, el auge de la musica urbana (HIP HOP), representa el segundo puesto. Aunque con una gran diferencia respecto al pop.

# %% [markdown]
# # Energia y valencia de los hits de las ultimas dos decadas

# %%
fig, ax = plt.subplots(figsize=(12,4))
plt.xlim(2000,2020)
sns.lineplot(data=df, x="year", y="energy", label= "Energia",ax=ax)
sns.lineplot(data=df, x="year", y="valence",label= "Valencia", ax=ax)
plt.title("Energia y valencia de los hits")
plt.xlabel("Año");
plt.ylabel("Porcentaje");

# %% [markdown]
# Cuando nos referimos a la energia de un tema, nos referimos a la medida percibida en cuanto a la intensidad y actividad de un tema. Y la valencia, refiere de cierta forma, al "estado de animo" que representa la canción. Siendo mayor la valencia en temas alegres o euforicos y menos en temas mas tristes o que representen emociones negativas.
#
# Como se puede ver, de cierta forma, se empieza a dar una correlación entre la valencia y la energia a partir de los 10'. Lo que podria explicarse como una mayor coherencia musical entre ambos aspectos.

# %% [markdown]
# En base a la comparación anterior, planteamos un grafico en el que se pueda determinar la relación entre la energia de un HIT y su popularidad durante las ultimas dos décadas.

# %%
fig, ax = plt.subplots(figsize=(12,4))
sns.scatterplot(data=df, x="energy", y="popularity", hue="year", palette="Greens", ax=ax)
plt.ylim(20, 90)
plt.title("Popularidad según el nivel de energía de un HIT entre 2000 y 2020")
plt.xlabel("Energía")
plt.ylabel("Popularidad")
plt.legend(title="Año")
plt.show()

# %% [markdown]
# Como se puede observar, las canciones cuyo valor energetico se valora por encima de 0.5, presentan una popularidad, generalmente, mayor a 50 (en una escala del 1 al 100).
#
#  Ademas, es posible determinar que la gran mayoria de las canciones que forman parte del dataset, poseen un nivel energetico mayor al marcado anteriormente.
#
#  Esto puede demostrar que desde hace 20 años atras, las canciones mas relevantes suelen plantear ritmos bastante energeticos, esto puede tener diferentes efectos en sus oyentes, dependiendo de la persona y del contexto en el que se escucha la música. Sin embargo, en general, una canción con mucha energía puede causar asimismo un aumento de la misma, un mejora del estado de ánimo, y una mayor concentración. Estados que son mayoritariamente anhelados en la sociedad actual.
#
# Aun así, es posible dilucidar que durante los últimos años, el factor "energía" no es determinante a la hora de generar una canción popular. Debido a que durante los últimos años, las canciones con un nivel energético algo más bajo comenzaron a tener una tendencia hacia una popularidad mayor.
#
# Una posible explicación para este fenómeno sería que la música refleja los cambios culturales y sociales de una época determinada. En los últimos años, ha habido un mayor énfasis en la salud mental, el bienestar y la relajación. Las canciones con un nivel de energía más bajo pueden resonar con audiencias que buscan calma y tranquilidad en medio del ajetreo de la vida moderna.

# %% [markdown]
# #Tonos musicales mas usados en los TOP 5 Generos

# %%
#TONOS MAS USADOS DE LOS TOP 5 GENEROS
notas = ['DO','DO#','RE','RE#','MI','FA','FA#','SOL','SOL#','LA','LA#','SI']
generos_counts = df["genre"].value_counts() #Funcion previamente usada
generos_top_5 = generos_counts.head(5) 
df_top_5 = df[df["genre"].isin(generos_top_5.index)]

plt.figure()
sns.countplot(x='key', hue='genre', data=df_top_5)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.xticks(np.arange(0, 12), notas)
plt.title("Tonos mas usados en top 5 generos")
plt.xlabel("Tono");
plt.ylabel("Cantidad");

# %% [markdown]
# Al contrario de lo que se hubiera especulado, en general no existe un tono en particular que defina la industria. Aun asi se puede observar, principalmente en el pop, que tonos como do, fa y sol son tonos sumamente relevantes para definir su impronta. En cuanto a los demas generos, se mantiene cierta correlación en los usos de los tonos. Aunque, planteando el Re sostenido, se puede ver que es el tono menos usado, y mas aún en el R&B. Esto puede ser consecuencia de las escalas convencionales que se utilizan en dicho genero.

# %% [markdown]
# #Tonos mas populares 2000-2020

# %%
fig, ax = plt.subplots(figsize=(12,4))
sns.boxplot(data=df, x='key', y='popularity')
plt.xticks(np.arange(0, 12), notas)
plt.title("Tonos mas populares")
plt.xlabel("Tono");
plt.ylabel("Popularidad");

# %% [markdown]
# Como se permite ver en el grafico, las velas no difieren mucho en popularidad entre si, por lo que se puede comprender que no hay un tono preferente a la hora de plantear canciones de exito. La unica vela que se puede entender con cierta superioridad en cuanto a popularidad es la de RE#, que ironicamente es el tono menos utilizado dentro del TOP. (Esto puede deberse a la poca cantidad de datos con respecto a los demas tonos, y por lo tanto, estar presentando un dato con un margen de error poco acotado)

# %% [markdown]
# # Relación entre el modo y la popularidad de un hit

# %%
fig, ax = plt.subplots(figsize=(8,8))
sns.boxplot(data=df, x="mode", y="popularity", color= "Green")
ax.set_xticklabels(["Menor", "Mayor"])
plt.title("Modo de los HITS")
plt.xlabel("Modo");
plt.ylabel("Popularidad");

# %% [markdown]
# Cuando nos referimos al modo en el que se encuentra una canción, nos referimos a si la tonalidad es mayor o menor. Las tonalidades mayores representan estados animicos mas positivos (felicidad, euforia, etc) y los menores, sentimientos mas sombrios o negativos (tristeza, melancolia, entre otros).
#
# Como se puede ver en el grafico, la diferencia de popularidad entre ambos modos es practicamente minima. Y la varianza, un poco inferior en el modo menor.
#
# En cuanto a los outliers, podemos observar una gran cantidad en ambos casos, por debajo de aproximadamente los 40 puntos. Aun asi, en las tonalidades menores, podemos observar una mayor densidad con un nivel superior de popularidad.

# %% [markdown]
# ---
#
#
# # INSIGHTS 📊
#
#
#
# *   Con el pasar de los años, hasta el 2020, las canciones con mas popularidad tienden a tener un rango de sonoridad mas amplio, pero siempre concentrandose entre los niveles mas cercanos al nivel de saturación de los equipos de audio.
# *   La duración media de las canciones mas populares esta entre los 204 y 220 segundos.
# *   El genero predominante en las canciones mas populares, entre 2000 y 2019, es el pop.
# *   La mayoria de exitos comerciales suelen tener una mayor "energia". Aunque esto no es un factor determinante en las últimas epocas.
# *   Centrandonos en el genero mas popular, que es el pop. Aquellas canciones que se encuentran en DO, FA o SOL. Son las que mas caracterizan al genero y tienen mayor probabilidad de exito.
# Sin embargo, no existe una tonalidad en particular que defina el exito de todas las canciones de todos los generos.
#
# # RECOMENDACIONES 📑
#
# Con los insights obtenidos, podemos inferir en que, para que una canción tenga un mayor exito comercial debe seguir una serie de pautas en base al genero al que pertenece.
#  Aun asi, mas allá del genero, hay ciertas componentes, sumamente relevantes, que pueden afectar al exito de la canción.
#
# *   La canción debe encontrarse entre un rango de sonoridad de entre -10 y -5 dBFS. En definitiva, debe tener la capacidad de alcanzar un nivel alto de volumen en los dispositivos de audio.
# *   La duración de la canción debe ser de aproximadamente 3 minutos y medio.
# *   Si se busca que la canción tenga mayor exito, tiene que ser parte del genero POP. O al menos tener ciertas componentes que la vuelvan una canción capaz de encasillarse en dicho genero.
# *   La intención de la canción debe tener un cierto nivel "energético". Es decir, que lleve a su oyente a experimentar sentimientos más intensos. Sin la necesidad de que sea un ritmo "frenético".
# *  Teniendo en cuenta que la canción posee ciertos componentes propios del POP, se debe procurar que las tonalidades sean, preferentemente, DO, FA o SOL. Ya que estas tienen mayor porcentaje de uso dentro de las canciones mas exitosas, ademas de que entre estas tonalidades existe cierta relación armonica que puede evocar ciertos sentimientos parecidos en los oyentes.

# %% [markdown]
# ---

# %% [markdown]
# #CORRELACIÓN ENTRE MEDIDAS

# %% [markdown]
# Un grafico importante, para poder determinar la correlación entre la popularidad de una canción y sus caracteristicas, es por medio de un heatmap en donde podamos obervar el nivel de correlación de cada caracteristicas con su popularidad.

# %%
#Selecciono columna popularidad
popularity = df[['popularity']];

# creo matriz de correlación
corr_matriz = df.corrwith(popularity['popularity']);

# Creo un nuevo dataFrame con la matriz de correlación
new_df = pd.DataFrame(corr_matriz, columns=['Popularidad']);

plt.figure(figsize=(7,8));
sns.heatmap(new_df, annot = True, fmt = '.2f');
plt.title('Correlación entre medidas', size = 20);
plt.yticks(fontsize=15);
plt.xticks(fontsize=15);
plt.show();
# Out:
# <ipython-input-106-470fe29b928a>:5: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matriz = df.corrwith(popularity['popularity']);

# %% [markdown]
# Como se puede observar, la correlación entre la popularidad de un HIT y el resto de caracteristicas es practicamente nula. Teniendo unicamente como valor maximo de correlación, la popularidad de la canción y su año de lanzamiento. Lo que puede deberse, principalmente, por el aumento de suscripciones en la plataforma en los ultimos años.

# %% [markdown]
# #BUSCANDO MEJORAR CORRELACIONES
# A continuación, separaremos el analisis por genero (Los mas populares) para corroborar si existe alguna correlación

# %%
df_pop = df[df["genre"] == "pop"];


pop_col = df_pop['popularity'];


corr_matrix = df_pop.corrwith(pop_col);
# Out:
# <ipython-input-107-a3a868534a7e>:7: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df_pop.corrwith(pop_col);

# %%
plt.figure(figsize=(7,6))
sns.heatmap(corr_matrix.to_frame(), annot = True, fmt = '.2f')
plt.title('Correlación entre medidas del POP', size = 20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.show()

# %%
df_hpop = df[df["genre"] == "hip hop, pop"]


pop_col = df_hpop['popularity']


corr_matrix = df_hpop.corrwith(pop_col)

# Se limina la columna "numero_generos" del DataFrame corr_matrix
corr_matrix = corr_matrix.drop('numero_genero')
# Out:
# <ipython-input-109-d84836c63af7>:7: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df_hpop.corrwith(pop_col)

# %%
plt.figure(figsize=(7,6))
sns.heatmap(corr_matrix.to_frame(), annot = True, fmt = '.2f')
plt.title('Correlación entre medidas del Hip Hop, POP', size = 20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.show()

# %%
df_hpoprb = df[df["genre"] == "hip hop, pop, R&B"]


pop_col = df_hpoprb['popularity']


corr_matrix = df_hpoprb.corrwith(pop_col)
corr_matrix = corr_matrix.drop('numero_genero')
# Out:
# <ipython-input-111-f2d82cbdabcd>:7: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df_hpoprb.corrwith(pop_col)

# %%
plt.figure(figsize=(7,6))
sns.heatmap(corr_matrix.to_frame(), annot = True, fmt = '.2f')
plt.title('Correlación entre medidas del hip hop, pop, R&B', size = 20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.show()

# %%
df_popde = df[df["genre"] == "pop, Dance/Electronic"]


pop_col = df_popde['popularity']


corr_matrix = df_popde.corrwith(pop_col)

corr_matrix = corr_matrix.drop('numero_genero')
# Out:
# <ipython-input-113-f4f373e0129e>:7: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df_popde.corrwith(pop_col)

# %%
plt.figure(figsize=(7,6))
sns.heatmap(corr_matrix.to_frame(), annot = True, fmt = '.2f')
plt.title('Correlación entre medidas del pop, Dance/Electronic', size = 20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.show()

# %% [markdown]
# # 6. **REDUCCIÓN DE DIMENSIONALIDAD Y EVALUACIÓN DE MODELOS**

# %% [markdown]
# Con esta información, se creará un modelo de aprendizaje automático que puede predecir qué canciones tendrán un mayor éxito en el futuro cercano. El modelo analizará las características de las canciones para identificar que caracteristicas deberan tener las canciones que tienen el potencial de convertirse en hits, siempre y cuando se plantee un ojo critico sobre como estas podrian incorporarse a las tendencias actuales, o mejor aún, que se puedan determinar exitos sin que la epoca sea un factor determinante.

# %% [markdown]
# A continuación reduciremos las features del dataset con el fin de conservar unicamente las mas relevantes a la hora de determinar que caracteristicas tienen las canciones HIT en la industria.
#
# Por lo que se plantean como las features relevantes para determinar la popularidad de un tema a la duración, el tono, la sonoridad, que tan bailable sea, año de lanzamiento, que tanta lirica contiene, su energia, su valencia y su nivel de instrumentalidad.

# %% [markdown]
# Planteamos las variables X e Y.

# %%
X = df[['duration_s','key','loudness','danceability','year','speechiness','energy','valence','instrumentalness']]       # feature matrix
Y = df['hit']               #feature objetivo

# %% [markdown]
# Se crea la siguiente función que se utiliza para dividir un conjunto de datos en dos subconjuntos aleatorios llamados conjuntos de entrenamiento y prueba. Se utiliza para entrenar y evaluar modelos de aprendizaje automático.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.20, random_state=42)

# %% [markdown]
# # - Árbol de decisiones

# %% [markdown]
# Como nuestro objetivo se plantea en la predicción de caracteristicas que tenga una canción para ser de exito o no, se utilizara un algoritmo de clasificación para determinar si las canciones en cuestión serán o no populares.
#
# En esta instancia, se tomó la decisión de utilizar como metodo de aprendizaje un árbol de decisiones.

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn import tree 

arbol = DecisionTreeClassifier(max_depth=5) #se plantean no mas de cuatro niveles en el arbol.

arbol.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
tree.plot_tree(arbol.fit(X_train,Y_train),filled=True,  impurity=True);

# %% [markdown]
# # Metricas
# Procedemos a determinar la exactitud del modelo.

# %%
from sklearn.metrics import accuracy_score, precision_score

Y_train_pred = arbol.predict(X_train)

Y_test_pred = arbol.predict(X_test)

print('porcentaje de aciertos sobre el conjunto de entrenamiento:', accuracy_score(Y_train_pred,Y_train))
print('porcentaje de aciertos sobre el conjunto de evaluación:', accuracy_score(Y_test_pred, Y_test))
# Out:
# porcentaje de aciertos sobre el conjunto de entrenamiento: 0.9293960923623446
# porcentaje de aciertos sobre el conjunto de evaluación: 0.9360568383658969

# %%
from sklearn import metrics
#Planteo metricas principales
print(metrics.classification_report(Y_test,Y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        35
#            1       0.94      1.00      0.97       528
#
#     accuracy                           0.94       563
#    macro avg       0.47      0.50      0.48       563
# weighted avg       0.88      0.94      0.91       563

# %%
# Crear matriz de confusión
confusion_matrix = metrics.confusion_matrix(Y_test, Y_test_pred)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])

cm_display.plot()
plt.show()

# %% [markdown]
# #Hiperparametros
# Establecemos el nivel de exactitud para las distintas profundidades de nuestro arbol de decisiones.

# %%
from sklearn.model_selection import cross_validate

tree_train_scores_mean = []
tree_train_scores_std = []
tree_test_scores_mean = []
tree_test_scores_std = []

profundidades = np.arange(1,30,1)

for profundidad in profundidades:

  clf = DecisionTreeClassifier(max_depth=4)
  tree_scores = cross_validate(clf, X, Y, cv=2, return_train_score=True, n_jobs = -1)

  tree_train_scores_mean.append(tree_scores['train_score'].mean())
  tree_train_scores_std.append(tree_scores['train_score'].std())
  tree_test_scores_mean.append(tree_scores['test_score'].mean())
  tree_test_scores_std.append(tree_scores['test_score'].std())

tree_train_scores_mean = np.array(tree_train_scores_mean)
tree_train_scores_std = np.array(tree_train_scores_std)
tree_test_scores_mean = np.array(tree_test_scores_mean)
tree_test_scores_std = np.array(tree_test_scores_std)

# %%
plt.fill_between(profundidades, tree_train_scores_mean - tree_train_scores_std, tree_train_scores_mean + tree_train_scores_std, alpha=0.1, color='r')
plt.fill_between(profundidades, tree_test_scores_mean - tree_test_scores_std, tree_test_scores_mean + tree_test_scores_std, alpha=0.1, color='g')
plt.plot(profundidades, tree_train_scores_mean, 'o-', color='r', label='Training score')
plt.plot(profundidades, tree_test_scores_mean, 'o-', color='g', label='Test score')

plt.legend()

plt.ylabel('Accuracy')
plt.xlabel('Depth Decision Tree')

plt.show()

# %% [markdown]
# Como se puede ver, ambas lineas se encuentran ampliamente separadas, cuando se busca que ambas tengan cierta correlación. Por lo que cuando comienza a subir el max_depth, se separa, por esta razón se puede asumir que tenemos overfitting.

# %% [markdown]
# #- KNN

# %% [markdown]
# A continuación utilizamos el KNN, con el fin de comparar con los resultados del modelo anterior.

# %%
from sklearn.neighbors import KNeighborsClassifier

#Planteamos modelo 
knn = KNeighborsClassifier(n_neighbors=20)

#Entrenamos modelo
knn.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=20)

# %% [markdown]
# Procedemos a plantear las metricas

# %%
from sklearn.metrics import accuracy_score
Y_test_pred = knn.predict(X_test) #Realizamos Predicción
Y_train_pred = knn.predict(X_train)

print('porcentaje de aciertos sobre el conjunto de entrenamiento:', accuracy_score(Y_train_pred,Y_train))
print('porcentaje de aciertos sobre el conjunto de evaluación:', accuracy_score(Y_test_pred, Y_test))
# Out:
# porcentaje de aciertos sobre el conjunto de entrenamiento: 0.9245115452930728
# porcentaje de aciertos sobre el conjunto de evaluación: 0.9378330373001776

# %%
from sklearn import metrics
#Planteo metricas principales
print(metrics.classification_report(Y_test,Y_test_pred));
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        35
#            1       0.94      1.00      0.97       528
#
#     accuracy                           0.94       563
#    macro avg       0.47      0.50      0.48       563
# weighted avg       0.88      0.94      0.91       563
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Crear matriz de confusión
confusion_matrix = metrics.confusion_matrix(Y_test, Y_test_pred)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])

cm_display.plot()
plt.show()

# %% [markdown]
# #- REGRESIÓN LOGARITMICA

# %% [markdown]
# Planteamos el modelo

# %%
from sklearn.linear_model import LogisticRegression
#Planteo modelo
lr = LogisticRegression()

#Lo ajusto
lr.fit(X_train, Y_train)

#Realizo predicciones
Y_test_pred3 = lr.predict(X_test)
Y_train_pred3 = lr.predict(X_train)

# %% [markdown]
# Obtenemos metricas

# %%
print('porcentaje de aciertos sobre el conjunto de entrenamiento:', accuracy_score(Y_train_pred3,Y_train))
print('porcentaje de aciertos sobre el conjunto de evaluación:', accuracy_score(Y_test_pred3, Y_test))
print('')
print('')
#Planteo metricas principales
print(metrics.classification_report(Y_test,Y_test_pred))

confusion_matrix = metrics.confusion_matrix(Y_test, Y_test_pred)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])

cm_display.plot()
plt.show()
# Out:
# porcentaje de aciertos sobre el conjunto de entrenamiento: 0.9245115452930728
# porcentaje de aciertos sobre el conjunto de evaluación: 0.9378330373001776
#
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        35
#            1       0.94      1.00      0.97       528
#
#     accuracy                           0.94       563
#    macro avg       0.47      0.50      0.48       563
# weighted avg       0.88      0.94      0.91       563
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Como se puede distinguir, en las matrices de confusión del metodo KNN y el de Regresión Logaritmica podemos encontrar valores nulos en la primer columna. Esto puede ocurrir por diversas razones, como por ejemplo:
#
# * El modelo no está bien ajustado y no está haciendo predicciones precisas.
# * El conjunto de datos utilizado para entrenar el modelo no era representativo o no incluía suficientes casos de verdaderos positivos o negativos.
# * La métrica utilizada para evaluar el modelo no es la adecuada para el problema en cuestión.

# %% [markdown]
# Por lo tanto, si nos centramos en el modelo de arbol de decisión. Podemos encontrarnos resultados en las metricas, mas eficientes y que indicarian en un comienzo, una predilección por dicho modelo. De todas formas, se puede comprobar en el grafico dentro de la sección de hiperparametros, que existe un sobreajuste por parte del modelo al encontrarse la linea de entrenamiento constante.

# %% [markdown]
# # VERIFICACIÓN DE OVERFITTING
# Observaremos el efecto del Overfitting en el entrenamiento y testeo de nuestros datos, lo cual ayudará a decidir qué modelo de clasificación funciona mejor para nuestros datos.

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import learning_curve
cv = KFold(n_splits=5)

def plot_learning_curve(estimator, title, X, Y, ylim=None, cv=None,
                        n_jobs=-1, train_sizes=np.linspace(.1, 1.0, 5)):
    """Generate a simple plot of the test and training learning curve"""
    plt.figure(figsize=(15,10))
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(estimator, X, Y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

plot_learning_curve(arbol, "Curva de aprendizaje del arbol de decisiones", X_train, Y_train, cv=cv)
plot_learning_curve(knn, "Curva de aprendizaje del KNN", X_train, Y_train, cv=cv)
plot_learning_curve(lr, "Curva de aprendizaje de la regresión logaritmica", X_train, Y_train, cv=cv)
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py'>

# %% [markdown]
# Como se puede observar en los graficos, los modelos de KNN y de Regresión logaritmica presentan inconvenientes en el momento en el que se cruzan ambas curvas de aprendizaje, lo que se traduce como un sobreajuste por parte del modelo.
#
# Por tal motivo, procedemos a elegir como modelo predilecto el del arbol de decisiones. Que si bien presenta cierto sobreajuste (como se puede observar en el gráfico de sus hiperparametros), no lo presenta al mismo nivel que los otros dos modelos. Ademas de que los porcentajes de acierto entre ambos conjuntos, de entrenamiento y de evaluación, son los mayores de entre todos los modelos.

# %% [markdown]
# # **CONCLUSIÓN**
#
# Por ende, podemos concluir en que el mejor modelo para poder predecir que caracteristicas presentará el proximo HIT de spotify, en base a los datos de los ultimos 20 años, es el modelo de arbol de decisiones. Con un 95% de aciertos en el conjunto de entrenamiento y un 86% en el conjunto de evaluación. Estos porcentajes podrian mejorarse con una selección de profundidad diferente, tomando de referencia el nivel en el cual ambos conjuntos se encuentran menos distantes entre si.
#
# De todas formas, se decide conservar los valores de esta manera, debido a que aquellos niveles de aciertos extremadamente algo, generarian inconvenientes al agregar nuevos datos al dataset. Lo que seria contraproducente, debido a que las distintas referencias musicales y sonoras seguiran cambiando durante los proximos años. Si el dataset conservara unicamente los datos de los ultimos 20 años, nos encontrariamos con el hecho de que solo se podrian predecir las tendencias mas recientes, de manera que este, en cierto punto, quedaria obsoleto.
